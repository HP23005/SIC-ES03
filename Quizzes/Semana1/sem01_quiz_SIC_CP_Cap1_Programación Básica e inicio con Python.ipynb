# %% [markdown]
# # Coding and Programming
#
# ## Capítulo 1
#
# ### Conceptos básicos de programación e iniciación con python
#
#
# - **Unidad 1**: Programación secuencial
# - **Unidad 2**: Planificación de la programación
# - **Unidad 3**: Fundamentos de los tipos de datos numéricos y operaciones aritméticas
# - **Unidad 4**: Variables y entradas (Inputs)
# - **Unidad 5**: Operaciones lógicas y de comparación
# - **Unidad 6**: Enunciado condicional-1: Condiciones y toma de decisiones
# - **Unidad 7**: Enunciado condicional-2: Tomar decisiones en dos direcciones y aplicar enunciados condicionales
# - **Unidad 8**: Bucle-1
# - **Unidad 9**: Bucle-2
#
# # Quiz 1

# %% [markdown]
# ___

# %% [markdown]
# ## Q 01-01
#
# El código que imprime los valores numéricos del 1 al 3 utilizando la función `print()` es `print(1+2+3)`.
#
# Con referencia a este código, imprima los valores de 1 a 5 de forma similar.
#
# **Respuesta:**

# %%
print(1 + 2 + 3 + 4 + 5) #Si se usa el signo "+" realiza una suma, mas no imprime los valores numericos como tal

print (1, 2, 3, 4, 5) #Usar una "," entre cada valor hace que se imprima cada valor numerico por separado
# Out:
# 15
# 1 2 3 4 5

# %% [markdown]
# ___

# %% [markdown]
# ## Q 02-01
#
# Un programa que calcula la suma de números impares entre enteros entre 1 y 100 e imprime el resultado.
#
# Completa los espacios en blanco de la segunda figura del siguiente diagrama de flujo.

# %% [markdown]
# ![sic_cp_quiz1_p02-01.png](attachment:sic_cp_quiz1_p02-01.png)
#
# ![image.png](attachment:109144b9-f1e1-4858-b521-e1e2b221a6c1.png)

# %%
N = 0
S = 0

while N <= 100:
    if N % 2 != 0:
        S += N
    N += 1

print("La suma de los numeros impares enteros entre 1 y 100 es: ", S)
# Out:
# La suma de los numeros impares enteros entre 1 y 100 es:  2500

# %% [markdown]
# ___

# %% [markdown]
# ## Q 02-02
#
# Un programa que reciba un número entero positivo del usuario y en indique si es un número par o impar.
#
# Complete el pseudocódigo apropiado para **___**.

# %%
'''
print("Ingrese un entero:")
n = input()
if ___:
    print("Es par")
else:
    print("Es impar")
'''

'''
print("Ingrese un entero:")
n = input()
if n % 2 ==0:
    print("Es par")
else:
    print("Es impar")
'''

'''
Algoritmo ParOImpar
    Escribir "Ingrese un entero:"
    Leer n
    Si n MOD 2 = 0 Entonces
        Escribir "Es par"
    Sino
        Escribir "Es impar"
    FinSi
FinAlgoritmo
'''

# %%
print("Ingrese un entero:")
n = int(input())
if n % 2 == 0:
    print("Es par")
else:
    print("Es impar")
# Out:
# Ingrese un entero:
#  35
# Es impar

# %% [markdown]
# ___

# %% [markdown]
# ## Q 03-01
#
# El Código para imprimir la siguiente salida decorativa.
#
# `***********************************`
#
# `###################################`
#
#
# Utilice sólo un carácter '*' en la primera línea y use el operador * y número.
#
# En la segunda línea, utilice sólo un carácter '#' y un espacio, y utilice el operador * y el número.
#
# **Guía de codificación:**
#
# - En el caso de la primera línea, imprima de la misma manera que '*' * número n.
#
# - La segunda línea también utiliza el operador *.
#
#
# **Respuesta:**

# %%
n = int(input("Ingrese la cantidad de caracteres que necesite: "))

c1 = "*"
c2 = "#"

print(c1 * n)
print(c2 * n)
# Out:
# Ingrese la cantidad de caracteres que necesite:  40
# ****************************************
# ########################################

# %% [markdown]
# ___

# %% [markdown]
# ## Q 04-01
#
# Escribe y guarda tu nombre y dirección en las variables nombre y dirección, respectivamente.
#
# Escribe un código que lo imprima en la pantalla de la siguiente manera.
#
# **Guía de codificación:** Utiliza una variable como `nombre = 'Mi nombre'`.
#
# **Respuesta:**

# %%
nombre = 'José Iván Hernández Portillo'
direccion = 'Col. Llano El Espino 2da Etapa Pje#7 Casa#5'

print("Mi nombre es: ", nombre)
print("Vivo en: ", direccion)
# Out:
# Mi nombre es:  José Iván Hernández Portillo
# Vivo en:  Col. Llano El Espino 2da Etapa Pje#7 Casa#5

# %% [markdown]
# ___

# %% [markdown]
# ## Q 05-01
#
# Espere el resultado del siguiente código y escríbalo.

# %% [markdown]
# ```
# x = 1
# y = 0
# print(x and y)
# print(x or y)
# print(not x)
# print(not y)
# ```

# %% [markdown]
# 0 #Ya que estamos evaluando x y y con un and, esto significa que si ambos no tienen el mismo valor nos dara 0, lo contrario de or que el que prevalece es el que tenga 1
#
#
# 1 #Ya que estamos evaluando x y y con un or, puede ser uno o el otro, pero el que prevalece es el que tiene como valor 1 y no 0
#
#
# False #Ya que al negar el valor de x (1) nos queda 0, el cuál es tomado como False
#
#
# True #Ya que al negar el valor de y (0) nos queda 1, el cuál es tomado como True

# %% [markdown]
# ___

# %% [markdown]
# ## Q 06-01
#
# Escriba un programa que tome dos enteros aleatorios como entrada y los enumere de menor a mayor.
#
# (Restricción: dos enteros distintos, es decir, que no sean el mismo número)
#
# **Pauta de codificación:**
# - Reciba la entrada del usuario con la función de entrada y conviértala en un número entero usando la función `int`.
# - Luego, use una declaración `if` para comparar e imprimir los dos valores.
#
# **Respuesta:**

# %%
entero1 = int(input("Ingrese el entero 1: "))
entero2 = int(input("Ingrese el entero 2: "))

while entero1 == entero2:
    print("Ambos numeros deben ser diferentes")
    entero1 = int(input("Ingrese el entero 1: "))
    entero2 = int(input("Ingrese el entero 2: "))
    
if entero1 > entero2:
    print(f"El entero 1 '{entero1}' es mayor que El entero 2 '{entero2}'")
else:
    print(f"El entero 2 '{entero2}' es mayor que El entero 1 '{entero1}'")
# Out:
# Ingrese el entero 1:  1
# Ingrese el entero 2:  1
# Ambos numeros deben ser diferentes
# Ingrese el entero 1:  2
# Ingrese el entero 2:  2
# Ambos numeros deben ser diferentes
# Ingrese el entero 1:  2
# Ingrese el entero 2:  4
# El entero 2 '4' es mayor que El entero 1 '2'

# %% [markdown]
# ___

# %% [markdown]
# ## Q 07-01
#
# Escriba un programa que realice las siguientes funciones utilizando una expresión condicional compuesta de una sentencia `if`.
#
# **Guía de codificación:**
# - Escriba un código que se ejecute de forma diferente dependiendo de si la respuesta a la primera pregunta es 0 o 1.

# %% [markdown]
# ¿Eres un adulto? (1 si es mayor de edad, 0 si es menor de edad): 1
# ¿Está casado? (1 si es casado, 0 si es soltero): 1
# Usted es un adulto que está casado.
#
# Las tres salidas posibles son:
# - Usted es un adulto que está casado.
# - Usted es un adulto que está soltero.
# - Usted es menor de edad.
#
# **Respuesta:**

# %%
edad = int(input("¿Eres un adulto? (1 para sí, 0 para no):"))

if edad == 1:
    estado_civil = int(input("¿Está casado? (1 para sí, 0 para no):"))
    if estado_civil == 1:
        print("\nUsted es un adulto que está casado")
    else:
        print("\nUsted es un adulto que está soltero")
else:
    print("\nUsted es menor de edad")
# Out:
# ¿Eres un adulto? (1 para sí, 0 para no): 0
# Usted es menor de edad

# %% [markdown]
# ___

# %% [markdown]
# ## Q 08-01
#
# Entre los números naturales positivos distintos del 1, un número que no es primo se llama número compuesto. Escribe los números primos y compuestos del 2 al 12 de la siguiente manera.
#
# **Pauta de codificación:**
# - use la instrucción `for` para resolver este problema.
# - Cuando se utiliza una instrucción `for` anidada, se debe usar una expresión para determinar un número primo en el lazo `for` interno.

# %% [markdown]
# ```
# 2 : Primo
# 3 : Primo
# 4 : Compuesto
# 5 : Primo
# 6 : Compuesto
# 7 : Primo
# 8 : Compuesto
# 9 : Compuesto
# 10 : Compuesto
# 11 : Primo
# 12 : Compuesto
# ```

# %%
for numero in range(2, 13):
    es_primo = True
    for i in range(2, numero):
        if numero % i == 0:
            es_primo = False
            break
    if es_primo:
        print(f"{numero} : Primo")
    else:
        print(f"{numero} : Compuesto")
# Out:
# 2 : Primo
# 3 : Primo
# 4 : Compuesto
# 5 : Primo
# 6 : Compuesto
# 7 : Primo
# 8 : Compuesto
# 9 : Compuesto
# 10 : Compuesto
# 11 : Primo
# 12 : Compuesto

# %% [markdown]
# ___

# %% [markdown]
# ## Q 09-01
#
# Un número de Armstrong es un número entero de tres dígitos que es igual a la suma de los cubos de cada dígito.
#
# Encuentre todos los números de Armstrong entre enteros de tres dígitos e imprímalos de la siguiente manera.
#
#
# **Pauta de codificación:** todos los números del 100 al 999 deben buscarse utilizando la instrucción `for`.
#
# **Respuesta:**

# %%
for numero in range(100, 1000):
    str_num = str(numero)
    
    unidad = int(str_num[2])
    decena = int(str_num[1])
    centena = int(str_num[0])

    suma_cubos = unidad**3 + decena**3 + centena**3

    if numero == suma_cubos:
        print(numero)
# Out:
# 153
# 370
# 371
# 407

# %% [markdown]
# ___

# %% [markdown]
# ## Fin
